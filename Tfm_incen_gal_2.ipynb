# %% [markdown]
# # Incedios en distritos forestales gallegos en función de especies y variables ambientales

# %% [markdown]
# Lo que haremos será obtener datos de mapas para crear dataframes.
# Disponemos de las siguientes imágenes:

# %%
from PIL import Image
 
horas_sol = Image.open("imagenes df2/horas de sol anuales 2017.jpg")
horas_sol
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x2C10A9DA070>

# %%
precipit_anual = Image.open("imagenes df2/precipitacion anual galicia.jpg")
precipit_anual
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x451 at 0x2C10A9DAB20>

# %%
incendios_decada = Image.open("imagenes df2/superficie incendios 11-20.png")
incendios_decada
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=585x593 at 0x2C10A9F61C0>

# %%
ocupacion_especies = Image.open("imagenes df2/mapa-especie-forestal-galicia-2005-8.jpg")
ocupacion_especies
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x603 at 0x2C10A9DAA60>

# %% [markdown]
# Tenemos pues los siguientes datos:
#
# 1-Predictoras:
# 1.1. Climáticas: horas de sol anuales, mm anuales y días de lluvia anuales
# 1.2. Biológicas: % ocupación de caducifolias, eucaliptos y coníferas
#
# 2-Target: Hectareas afectadas a lo largo de una década

# %% [markdown]
# Pasos:
#
# 1- Separar imágenes con varios mapas
#
# 2- Teselar todos los mapas de la misma forma
#
# 3- Obtener valores por tesela para cada mapa
#
# 4- Crear un df
#
# 5- Entrenar un algoritmo
#
# 6- Crear columnas de ocupación de especies hipotéticas
#
# 7- Ver cómo cambia la predicción de incendios

# %% [markdown]
# Uso de imágenes para crear dataframes
#
# Ver todo lo que se pueda en internet y ver qué sirve.
#
# Links:
#
# 1- https://stackoverflow.com/questions/49649215/pandas-image-to-dataframe
#     esta puede ser útil: convierte imagen en vector de superficie y color (rgb)
#
# 2- https://towardsdatascience.com/rendering-images-inside-a-pandas-dataframe-3631a4883f60
#     Este mete imagenes en un data frame, no tiene mucho sentido
#
# 3- https://stackoverflow.com/questions/71162678/how-to-properly-extract-information-from-bounded-regions-from-images-using-openc
#     Esta parece muy interesante
